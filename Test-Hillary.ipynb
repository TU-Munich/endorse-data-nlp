# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from services.pipeline_service import *

# %%
handle_notebook_document("hillary","test","Barack Obama is the 44th president of the USA.", save=False)
# Out:
# {'timestamp': 1545301906.851406,
#  'input': 'Barack Obama is the 44th president of the USA.',
#  'lang': 'en',
#  'sentences': ['Barack Obama is the 44th president of the USA.'],
#  'sentiment': {'total': {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#   'sentences': [{'input': 'Barack Obama is the 44th president of the USA.',
#     'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}}]},
#  'pos': [{'text': 'Barack',
#    'lemma': 'barack',
#    'pos': 'PROPN',
#    'tag': 'NNP',
#    'dep': 'compound',
#    'shape': 'Xxxxx',
#    'is_alpha': True,
#    'is_stop': False},
#   {'text': 'Obama',
#    'lemma': 'obama',
#    'pos': 'PROPN',
#    'tag': 'NNP',
#    'dep': 'nsubj',
#    'shape': 'Xxxxx',
#    'is_alpha': True,
#    'is_stop': False},
#   {'text': 'is',
#    'lemma': 'be',
#    'pos': 'VERB',
#    'tag': 'VBZ',
#    'dep': 'ROOT',
#    'shape': 'xx',
#    'is_alpha': True,
#    'is_stop': True},
#   {'text': 'the',
#    'lemma': 'the',
# ...

# %% [markdown]
# ## Hillary Clinto Emails

# %%
import pandas as pd
df = pd.read_csv('./data/projects/hillary/Emails.csv')
df = df.fillna("")

# %%
df.head()
# Out:
#    Id  DocNumber                                    MetadataSubject  \
# 0   1  C05739545                                                WOW
# 1   2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2   3  C05739547                                      CHRIS STEVENS
# 3   4  C05739550                         CAIRO CONDEMNATION - FINAL
# 4   5  C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
#
#      MetadataTo       MetadataFrom SenderPersonId           MetadataDateSent  \
# 0             H  Sullivan, Jacob J             87  2012-09-12T04:00:00+00:00
# 1             H                                    2011-03-03T05:00:00+00:00
# 2            ;H    Mills, Cheryl D             32  2012-09-12T04:00:00+00:00
# 3             H    Mills, Cheryl D             32  2012-09-12T04:00:00+00:00
# 4  Abedin, Huma                  H             80  2011-03-11T05:00:00+00:00
#
#         MetadataDateReleased  \
# 0  2015-05-22T04:00:00+00:00
# 1  2015-05-22T04:00:00+00:00
# ...

# %%
for index, row in df.iterrows():
    doc_text = row['ExtractedBodyText'].strip()
    doc_name = row['DocNumber']
    if len(doc_text) > 10:
        doc_text = (doc_text[:500000] + '..') if len(doc_text) > 500000 else doc_text
        print(index)
        try:
            handle_notebook_document("hillary",doc_name,doc_text)
            pass
        except:
            pass
# Out:
# 1
# 4
# 5
# 7
# 9
# 11
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 21
# 23
# 25
# 27
# 28
# 29
# 31
# 32
# 33
# 36
# 38
# 39
# 41
# 43
# 45
# 46
# 47
# 49
# 50
# 51
# 52
# 53
# 54
# 55
# 57
# 58
# 60
# 61
# 64
# 65
# 66
# 67
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 80
# 81
# 82
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 96
# 97
# 98
# 100
# 101
# 102
# 103
# 105
# 106
# 107
# 108
# 109
# 110
# 112
# 113
# 114
# 115
# 117
# 118
# 120
# 121
# 122
# 123
# 124
# 126
# 127
# 129
# 130
# 131
# 132
# 133
# 135
# 136
# 138
# 140
# 141
# 142
# 143
# 146
# 147
# 148
# 151
# 152
# 154
# 157
# 158
# 159
# 160
# 161
# 162
# 164
# 167
# 168
# 169
# 171
# 173
# 174
# 175
# 176
# 178
# 179
# 182
# 184
# 185
# 186
# 187
# 190
# 192
# 193
# 194
# 195
# 196
# 198
# 200
# 201
# 202
# 204
# 206
# 209
# 211
# 212
# 213
# 214
# 216
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 228
# 229
# 230
# 232
# 234
# 235
# 236
# 237
# 239
# 240
# 241
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# ...

# %%
print("done")
# Out:
# done
